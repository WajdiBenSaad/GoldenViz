# %% [markdown]
# # GoldenViz examples: 25 rules
#
# Each example is a complete, standalone Matplotlib snippet. The good-chart code highlights the lines that were added or corrected.

# %% [markdown]
# <style>
# .gv-example-grid { display: grid; grid-template-columns: minmax(330px, 1fr) minmax(380px, 1.1fr); gap: 24px; align-items: center; margin: 18px 0 34px; }
# .gv-example-code { border: 1px solid #d9aa6f; background: #fffaf2; padding: 14px 16px; border-radius: 6px; overflow-x: visible; min-width: 0; }
# .gv-example-code.bad { border-left: 5px solid #b42318; }
# .gv-example-code.good { border-left: 5px solid #2f855a; }
# .gv-code-details summary { cursor: pointer; font-weight: 700; margin-bottom: 10px; color: #3b2b20; }
# .gv-example-code.bad .gv-code-details summary { color: #b42318; }
# .gv-example-code.good .gv-code-details summary { color: #2f855a; }
# .gv-code-details[open] summary { margin-bottom: 12px; }
# .gv-code-details summary p { display: inline; margin: 0; }
# .gv-example-code pre { margin: 0; white-space: pre-wrap !important; overflow-wrap: anywhere; word-break: normal; font-size: 0.76rem; line-height: 1.42; overflow-x: visible !important; }
# .gv-code-line { white-space: pre-wrap; }
# .gv-code-line.added { background: #e7f6ed; border-left: 3px solid #2f855a; padding-left: 5px; padding-right: 5px; color: #14532d; font-weight: 600; -webkit-box-decoration-break: clone; box-decoration-break: clone; }
# .gv-example-chart img { width: 100%; max-width: 720px; border: 1px solid #d9aa6f; border-radius: 6px; background: #fff7ec; }
# @media (max-width: 900px) { .gv-example-grid { grid-template-columns: 1fr; } }
# </style>

# %% [markdown]
# ## Installation check output
#
# This cell reproduces the installation smoke test. The first output is the Matplotlib chart; the second output is the GoldenViz report embedded as HTML.

# %%
import matplotlib.pyplot as plt
from IPython.display import HTML, display
from pathlib import Path
import GoldenViz as gv

fig, ax = plt.subplots(figsize=(6, 3.2))
ax.plot([2021, 2022, 2023], [10, 13, 16])
ax.set_title("Revenue trend by year")
ax.set_xlabel("Year")
ax.set_ylabel("Revenue (M EUR)")

# The chart output appears first.
display(fig)

# GoldenViz analyzes the figure; the HTML report below is embedded in this notebook.
report = gv.analyze(fig)
report_html = Path("_static/goldenviz_installation_check_report.html")
if not report_html.exists():
    report_html = Path("docs/_static/goldenviz_installation_check_report.html")
display(HTML(report_html.read_text(encoding="utf-8")))
plt.close(fig)
# Out:
#     <div style='margin:16px 0 8px 0;border:1px solid #e4e7ec;border-radius:16px;padding:16px 18px;background:white;box-shadow:0 1px 2px rgba(16,24,40,.06);font-family:Inter,Segoe UI,Arial,sans-serif;text-align:left;'>
#       <div style='display:flex;align-items:flex-start;justify-content:space-between;gap:12px;flex-wrap:wrap;text-align:left;'>
#         <span style='display:block;'>
#           <span style='display:block;font-size:18px;font-weight:800;color:#101828;'>GoldenViz report</span>
#           <span style='display:block;font-size:13px;color:#475467;margin-top:4px;'>Automatic visual QA for the 25 Golden Rules.</span>
#         </span>
#       </div>
#       <div style='display:flex;gap:10px;flex-wrap:wrap;margin-top:14px;'>
#         <span style='padding:4px 8px;border-radius:999px;background:#ecfdf3;color:#067647;font-weight:700;font-size:12px;'>PASS 25</span>
# ...

# %% [markdown]
# ## Completeness rules
#
# Rules 1-6 check whether the chart contains enough information to be understood on its own.

# %% [markdown]
# ### Rule 1 · Clear title
#
# A title should tell the reader what the chart is about before they inspect the marks.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">months = [&quot;Jan&quot;, &quot;Feb&quot;, &quot;Mar&quot;, &quot;Apr&quot;, &quot;May&quot;, &quot;Jun&quot;]</span>
# <span class="gv-code-line">revenue = [18, 20, 21, 23, 25, 28]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.plot(months, revenue, marker=&quot;o&quot;)</span>
# <span class="gv-code-line">ax.set_xlabel(&quot;Month&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Revenue (k EUR)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_01_bad.png" alt="Rule 1 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">months = [&quot;Jan&quot;, &quot;Feb&quot;, &quot;Mar&quot;, &quot;Apr&quot;, &quot;May&quot;, &quot;Jun&quot;]</span>
# <span class="gv-code-line">revenue = [18, 20, 21, 23, 25, 28]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.plot(months, revenue, marker=&quot;o&quot;)</span>
# <span class="gv-code-line added">ax.set_title(&quot;Monthly revenue increased from Jan to Jun 2026&quot;)</span>
# <span class="gv-code-line">ax.set_xlabel(&quot;Month&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Revenue (k EUR)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_01_good.png" alt="Rule 1 good chart example">
#   </div>
# </div>

# %% [markdown]
# ### Rule 2 · Axis labels
#
# Axis labels and units make the measurement unambiguous.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">ad_spend = [8, 12, 16, 20, 24, 30, 34, 38]</span>
# <span class="gv-code-line">signups = [110, 140, 175, 205, 245, 310, 335, 390]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.scatter(ad_spend, signups)</span>
# <span class="gv-code-line">ax.set_title(&quot;Campaign performance&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_02_bad.png" alt="Rule 2 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">ad_spend = [8, 12, 16, 20, 24, 30, 34, 38]</span>
# <span class="gv-code-line">signups = [110, 140, 175, 205, 245, 310, 335, 390]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.scatter(ad_spend, signups)</span>
# <span class="gv-code-line">ax.set_title(&quot;Campaign performance&quot;)</span>
# <span class="gv-code-line added">ax.set_xlabel(&quot;Ad spend (k EUR)&quot;)</span>
# <span class="gv-code-line added">ax.set_ylabel(&quot;New signups&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_02_good.png" alt="Rule 2 good chart example">
#   </div>
# </div>

# %% [markdown]
# ### Rule 3 · Units and scale clarity
#
# Large values should be scaled and labeled so the reader knows what the numbers mean.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">years = [2022, 2023, 2024, 2025]</span>
# <span class="gv-code-line">revenue = [1250000, 1480000, 1730000, 1910000]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.plot(years, revenue, marker=&quot;o&quot;)</span>
# <span class="gv-code-line">ax.set_title(&quot;Revenue trend&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Revenue&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_03_bad.png" alt="Rule 3 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">years = [2022, 2023, 2024, 2025]</span>
# <span class="gv-code-line">revenue = [1250000, 1480000, 1730000, 1910000]</span>
# <span class="gv-code-line added">revenue_millions = [value / 1_000_000 for value in revenue]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line added">ax.plot(years, revenue_millions, marker=&quot;o&quot;)</span>
# <span class="gv-code-line">ax.set_title(&quot;Revenue trend&quot;)</span>
# <span class="gv-code-line added">ax.set_xlabel(&quot;Year&quot;)</span>
# <span class="gv-code-line added">ax.set_ylabel(&quot;Revenue (million EUR)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_03_good.png" alt="Rule 3 good chart example">
#   </div>
# </div>

# %% [markdown]
# ### Rule 4 · Legend clarity
#
# Multiple series need clear labels so readers can identify each line.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">years = [2021, 2022, 2023, 2024, 2025]</span>
# <span class="gv-code-line">series = {</span>
# <span class="gv-code-line">    &quot;Basic&quot;: [12, 14, 16, 18, 20],</span>
# <span class="gv-code-line">    &quot;Pro&quot;: [9, 13, 17, 22, 28],</span>
# <span class="gv-code-line">    &quot;Enterprise&quot;: [6, 8, 12, 17, 25],</span>
# <span class="gv-code-line">}</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">for values in series.values():</span>
# <span class="gv-code-line">    ax.plot(years, values, marker=&quot;o&quot;)</span>
# <span class="gv-code-line">ax.set_title(&quot;Subscriptions by plan&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Subscriptions (k)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_04_bad.png" alt="Rule 4 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">years = [2021, 2022, 2023, 2024, 2025]</span>
# <span class="gv-code-line">series = {</span>
# <span class="gv-code-line">    &quot;Basic&quot;: [12, 14, 16, 18, 20],</span>
# <span class="gv-code-line">    &quot;Pro&quot;: [9, 13, 17, 22, 28],</span>
# <span class="gv-code-line">    &quot;Enterprise&quot;: [6, 8, 12, 17, 25],</span>
# <span class="gv-code-line">}</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line added">for label, values in series.items():</span>
# <span class="gv-code-line added">    ax.plot(years, values, marker=&quot;o&quot;, label=label)</span>
# <span class="gv-code-line added">ax.legend(loc=&quot;center left&quot;, bbox_to_anchor=(1.02, 0.5))</span>
# <span class="gv-code-line">ax.set_title(&quot;Subscriptions by plan&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Subscriptions (k)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_04_good.png" alt="Rule 4 good chart example">
#   </div>
# </div>

# %% [markdown]
# ### Rule 5 · Annotation context
#
# Important events or takeaways should be visible when they explain the pattern.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">weeks = [1, 2, 3, 4, 5, 6, 7, 8]</span>
# <span class="gv-code-line">adoption = [12, 15, 18, 23, 34, 39, 43, 46]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.plot(weeks, adoption, marker=&quot;o&quot;)</span>
# <span class="gv-code-line">ax.set_title(&quot;Feature adoption&quot;)</span>
# <span class="gv-code-line">ax.set_xlabel(&quot;Week&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Adoption (%)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_05_bad.png" alt="Rule 5 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">weeks = [1, 2, 3, 4, 5, 6, 7, 8]</span>
# <span class="gv-code-line">adoption = [12, 15, 18, 23, 34, 39, 43, 46]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.plot(weeks, adoption, marker=&quot;o&quot;)</span>
# <span class="gv-code-line added">ax.annotate(&quot;Onboarding email launched&quot;, xy=(5, 34), xytext=(3.2, 42), arrowprops={&quot;arrowstyle&quot;: &quot;-&gt;&quot;})</span>
# <span class="gv-code-line added">ax.set_title(&quot;Feature adoption increased after onboarding email&quot;)</span>
# <span class="gv-code-line">ax.set_xlabel(&quot;Week&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Adoption (%)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_05_good.png" alt="Rule 5 good chart example">
#   </div>
# </div>

# %% [markdown]
# ### Rule 6 · Uncertainty cues
#
# Estimates should show uncertainty when the uncertainty matters.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">groups = [&quot;A&quot;, &quot;B&quot;, &quot;C&quot;, &quot;D&quot;]</span>
# <span class="gv-code-line">mean = [52, 57, 61, 55]</span>
# <span class="gv-code-line">error = [4, 7, 3, 6]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.bar(groups, mean)</span>
# <span class="gv-code-line">ax.set_title(&quot;Average test result&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Score&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_06_bad.png" alt="Rule 6 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">groups = [&quot;A&quot;, &quot;B&quot;, &quot;C&quot;, &quot;D&quot;]</span>
# <span class="gv-code-line">mean = [52, 57, 61, 55]</span>
# <span class="gv-code-line">error = [4, 7, 3, 6]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line added">ax.bar(groups, mean, yerr=error, capsize=6)</span>
# <span class="gv-code-line added">ax.set_title(&quot;Average test result with uncertainty&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Score&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_06_good.png" alt="Rule 6 good chart example">
#   </div>
# </div>

# %% [markdown]
# ## Readability rules
#
# Rules 7-16 check whether the chart can be read, scanned, and compared without unnecessary effort.

# %% [markdown]
# ### Rule 7 · Readable labels
#
# Long labels should not collide or force the reader to decode a crowded axis.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">segments = [</span>
# <span class="gv-code-line">    &quot;Returning enterprise customers&quot;,</span>
# <span class="gv-code-line">    &quot;New small business customers&quot;,</span>
# <span class="gv-code-line">    &quot;One-time promotional buyers&quot;,</span>
# <span class="gv-code-line">    &quot;Students using education plan&quot;,</span>
# <span class="gv-code-line">    &quot;Trial users awaiting onboarding&quot;,</span>
# <span class="gv-code-line">]</span>
# <span class="gv-code-line">counts = [180, 145, 96, 125, 72]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.bar(segments, counts)</span>
# <span class="gv-code-line">ax.set_title(&quot;Customers by segment&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_07_bad.png" alt="Rule 7 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line">import textwrap</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">segments = [</span>
# <span class="gv-code-line">    &quot;Returning enterprise customers&quot;,</span>
# <span class="gv-code-line">    &quot;New small business customers&quot;,</span>
# <span class="gv-code-line">    &quot;One-time promotional buyers&quot;,</span>
# <span class="gv-code-line">    &quot;Students using education plan&quot;,</span>
# <span class="gv-code-line">    &quot;Trial users awaiting onboarding&quot;,</span>
# <span class="gv-code-line">]</span>
# <span class="gv-code-line">counts = [180, 145, 96, 125, 72]</span>
# <span class="gv-code-line added">labels = [textwrap.fill(s, 22) for s in segments]</span>
# <span class="gv-code-line added">pairs = sorted(zip(counts, labels))</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line added">ax.barh([label for _, label in pairs], [count for count, _ in pairs])</span>
# <span class="gv-code-line">ax.set_title(&quot;Customers by segment&quot;)</span>
# <span class="gv-code-line added">ax.set_xlabel(&quot;Customers&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_07_good.png" alt="Rule 7 good chart example">
#   </div>
# </div>

# %% [markdown]
# ### Rule 8 · Color accessibility
#
# Charts should remain readable for people with color-vision deficiencies.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">segments = [&quot;Home&quot;, &quot;Food&quot;, &quot;Auto&quot;, &quot;Health&quot;, &quot;Shopping&quot;]</span>
# <span class="gv-code-line">spend = [42, 26, 18, 12, 8]</span>
# <span class="gv-code-line">colors = [&quot;#d7191c&quot;, &quot;#fdae61&quot;, &quot;#ffffbf&quot;, &quot;#a6d96a&quot;, &quot;#1a9641&quot;]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.bar(segments, spend, color=colors)</span>
# <span class="gv-code-line">ax.set_title(&quot;Household spend by category&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Spend (%)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_08_bad.png" alt="Rule 8 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">segments = [&quot;Home&quot;, &quot;Food&quot;, &quot;Auto&quot;, &quot;Health&quot;, &quot;Shopping&quot;]</span>
# <span class="gv-code-line">spend = [42, 26, 18, 12, 8]</span>
# <span class="gv-code-line added">colors = [&quot;#0072B2&quot;, &quot;#E69F00&quot;, &quot;#56B4E9&quot;, &quot;#009E73&quot;, &quot;#CC79A7&quot;]</span>
# <span class="gv-code-line added">hatches = [&quot;&quot;, &quot;//&quot;, &quot;\\&quot;, &quot;..&quot;, &quot;xx&quot;]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">bars = ax.bar(segments, spend, color=colors)</span>
# <span class="gv-code-line added">for bar, hatch in zip(bars, hatches):</span>
# <span class="gv-code-line added">    bar.set_hatch(hatch)</span>
# <span class="gv-code-line">ax.set_title(&quot;Household spend by category&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Spend (%)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_08_good.png" alt="Rule 8 good chart example">
#   </div>
# </div>

# %% [markdown]
# ### Rule 9 · Direct labeling
#
# When lines are easy to label directly, readers should not have to bounce between the plot and legend.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">years = [2021, 2022, 2023, 2024, 2025]</span>
# <span class="gv-code-line">series = {</span>
# <span class="gv-code-line">    &quot;Basic&quot;: [12, 14, 16, 18, 20],</span>
# <span class="gv-code-line">    &quot;Pro&quot;: [9, 13, 17, 22, 28],</span>
# <span class="gv-code-line">    &quot;Enterprise&quot;: [6, 8, 12, 17, 25],</span>
# <span class="gv-code-line">    &quot;Education&quot;: [4, 7, 10, 13, 19],</span>
# <span class="gv-code-line">}</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">for label, values in series.items():</span>
# <span class="gv-code-line">    ax.plot(years, values, marker=&quot;o&quot;, label=label)</span>
# <span class="gv-code-line">ax.legend()</span>
# <span class="gv-code-line">ax.set_title(&quot;Subscriptions by plan&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Subscriptions (k)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_09_bad.png" alt="Rule 9 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">years = [2021, 2022, 2023, 2024, 2025]</span>
# <span class="gv-code-line">series = {</span>
# <span class="gv-code-line">    &quot;Basic&quot;: [12, 14, 16, 18, 20],</span>
# <span class="gv-code-line">    &quot;Pro&quot;: [9, 13, 17, 22, 28],</span>
# <span class="gv-code-line">    &quot;Enterprise&quot;: [6, 8, 12, 17, 25],</span>
# <span class="gv-code-line">    &quot;Education&quot;: [4, 7, 10, 13, 19],</span>
# <span class="gv-code-line">}</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">for label, values in series.items():</span>
# <span class="gv-code-line">    ax.plot(years, values, marker=&quot;o&quot;)</span>
# <span class="gv-code-line added">    ax.text(years[-1] + 0.05, values[-1], label, va=&quot;center&quot;)</span>
# <span class="gv-code-line added">ax.set_xlim(2021, 2025.9)</span>
# <span class="gv-code-line">ax.set_title(&quot;Subscriptions by plan&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Subscriptions (k)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_09_good.png" alt="Rule 9 good chart example">
#   </div>
# </div>

# %% [markdown]
# ### Rule 10 · Avoid chartjunk
#
# Decoration should not compete with the data.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">regions = [&quot;North&quot;, &quot;South&quot;, &quot;East&quot;, &quot;West&quot;]</span>
# <span class="gv-code-line">profit = [18, 12, 15, 21]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.set_facecolor(&quot;#f3d9a5&quot;)</span>
# <span class="gv-code-line">ax.bar(regions, profit, edgecolor=&quot;black&quot;, linewidth=2)</span>
# <span class="gv-code-line">ax.grid(True, axis=&quot;both&quot;)</span>
# <span class="gv-code-line">ax.set_title(&quot;!!! PROFIT !!!&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Profit (k EUR)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_10_bad.png" alt="Rule 10 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">regions = [&quot;North&quot;, &quot;South&quot;, &quot;East&quot;, &quot;West&quot;]</span>
# <span class="gv-code-line">profit = [18, 12, 15, 21]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line added">ax.bar(regions, profit)</span>
# <span class="gv-code-line added">ax.grid(True, axis=&quot;y&quot;)</span>
# <span class="gv-code-line added">ax.set_title(&quot;Profit by region&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Profit (k EUR)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_10_good.png" alt="Rule 10 good chart example">
#   </div>
# </div>

# %% [markdown]
# ### Rule 11 · Too many categories
#
# Too many categories make comparison slow and crowded.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">categories = [f&quot;C{i}&quot; for i in range(1, 19)]</span>
# <span class="gv-code-line">values = [34, 28, 26, 22, 20, 18, 16, 12, 11, 10, 9, 8, 7, 6, 5, 5, 4, 3]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.bar(categories, values)</span>
# <span class="gv-code-line">ax.set_title(&quot;Requests by category&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Requests&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_11_bad.png" alt="Rule 11 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">categories = [f&quot;C{i}&quot; for i in range(1, 19)]</span>
# <span class="gv-code-line">values = [34, 28, 26, 22, 20, 18, 16, 12, 11, 10, 9, 8, 7, 6, 5, 5, 4, 3]</span>
# <span class="gv-code-line added">top_labels = categories[:7] + [&quot;Other&quot;]</span>
# <span class="gv-code-line added">top_values = values[:7] + [sum(values[7:])]</span>
# <span class="gv-code-line added">pairs = sorted(zip(top_values, top_labels))</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line added">ax.barh([label for _, label in pairs], [value for value, _ in pairs])</span>
# <span class="gv-code-line">ax.set_title(&quot;Requests by category&quot;)</span>
# <span class="gv-code-line added">ax.set_xlabel(&quot;Requests&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_11_good.png" alt="Rule 11 good chart example">
#   </div>
# </div>

# %% [markdown]
# ### Rule 12 · Sort categorical bars
#
# Sorted bars make ranking and comparison faster.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">teams = [&quot;Ops&quot;, &quot;Sales&quot;, &quot;Support&quot;, &quot;Product&quot;, &quot;Finance&quot;]</span>
# <span class="gv-code-line">hours = [42, 18, 31, 24, 36]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.barh(teams, hours)</span>
# <span class="gv-code-line">ax.set_title(&quot;Average resolution time&quot;)</span>
# <span class="gv-code-line">ax.set_xlabel(&quot;Hours&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_12_bad.png" alt="Rule 12 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">teams = [&quot;Ops&quot;, &quot;Sales&quot;, &quot;Support&quot;, &quot;Product&quot;, &quot;Finance&quot;]</span>
# <span class="gv-code-line">hours = [42, 18, 31, 24, 36]</span>
# <span class="gv-code-line added">pairs = sorted(zip(hours, teams))</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line added">ax.barh([team for _, team in pairs], [hour for hour, _ in pairs])</span>
# <span class="gv-code-line">ax.set_title(&quot;Average resolution time&quot;)</span>
# <span class="gv-code-line">ax.set_xlabel(&quot;Hours&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_12_good.png" alt="Rule 12 good chart example">
#   </div>
# </div>

# %% [markdown]
# ### Rule 13 · Scatter overplotting
#
# Repeated or dense points should reveal density instead of hiding it.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line">import numpy as np</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">rng = np.random.default_rng(42)</span>
# <span class="gv-code-line">centers = np.array([[2, 2], [3, 3], [4, 2.5], [4.5, 4]])</span>
# <span class="gv-code-line">points = np.repeat(centers, [35, 45, 25, 30], axis=0)</span>
# <span class="gv-code-line">points = points + rng.normal(0, 0.04, size=(135, 2))</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.scatter(points[:, 0], points[:, 1], s=28)</span>
# <span class="gv-code-line">ax.set_xlabel(&quot;Value score&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Satisfaction score&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_13_bad.png" alt="Rule 13 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line">import numpy as np</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">centers = np.array([[2, 2], [3, 3], [4, 2.5], [4.5, 4]])</span>
# <span class="gv-code-line">counts = np.array([35, 45, 25, 30])</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line added">ax.scatter(centers[:, 0], centers[:, 1], s=counts * 18, alpha=0.55, edgecolor=&quot;black&quot;)</span>
# <span class="gv-code-line">ax.set_xlabel(&quot;Value score&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Satisfaction score&quot;)</span>
# <span class="gv-code-line added">ax.set_title(&quot;Point size shows repeated observations&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_13_good.png" alt="Rule 13 good chart example">
#   </div>
# </div>

# %% [markdown]
# ### Rule 14 · Decimal precision
#
# Labels should avoid unnecessary decimals that add noise without adding meaning.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">products = [&quot;A&quot;, &quot;B&quot;, &quot;C&quot;, &quot;D&quot;]</span>
# <span class="gv-code-line">conversion = [12.3421, 11.9874, 13.2251, 12.7718]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">bars = ax.bar(products, conversion)</span>
# <span class="gv-code-line">ax.bar_label(bars, fmt=&quot;%.4f%%&quot;)</span>
# <span class="gv-code-line">ax.set_ylim(0, 15)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Conversion (%)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_14_bad.png" alt="Rule 14 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">products = [&quot;A&quot;, &quot;B&quot;, &quot;C&quot;, &quot;D&quot;]</span>
# <span class="gv-code-line">conversion = [12.3421, 11.9874, 13.2251, 12.7718]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">bars = ax.bar(products, conversion)</span>
# <span class="gv-code-line added">ax.bar_label(bars, fmt=&quot;%.1f%%&quot;)</span>
# <span class="gv-code-line">ax.set_ylim(0, 15)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Conversion (%)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_14_good.png" alt="Rule 14 good chart example">
#   </div>
# </div>

# %% [markdown]
# ### Rule 15 · Date axis formatting
#
# Date ticks should be formatted at a readable interval.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line">import numpy as np</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">dates = [np.datetime64(&quot;2026-01-01&quot;) + np.timedelta64(i * 14, &quot;D&quot;) for i in range(10)]</span>
# <span class="gv-code-line">visits = [120, 135, 128, 150, 162, 158, 170, 181, 190, 205]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.plot(dates, visits, marker=&quot;o&quot;)</span>
# <span class="gv-code-line">ax.set_title(&quot;Website visits&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Visits (k)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_15_bad.png" alt="Rule 15 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line">import matplotlib.dates as mdates</span>
# <span class="gv-code-line">import numpy as np</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">dates = [np.datetime64(&quot;2026-01-01&quot;) + np.timedelta64(i * 14, &quot;D&quot;) for i in range(10)]</span>
# <span class="gv-code-line">visits = [120, 135, 128, 150, 162, 158, 170, 181, 190, 205]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.plot(dates, visits, marker=&quot;o&quot;)</span>
# <span class="gv-code-line">ax.set_title(&quot;Website visits&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Visits (k)&quot;)</span>
# <span class="gv-code-line added">ax.xaxis.set_major_locator(mdates.MonthLocator())</span>
# <span class="gv-code-line added">ax.xaxis.set_major_formatter(mdates.DateFormatter(&quot;%b %Y&quot;))</span>
# <span class="gv-code-line added">ax.tick_params(axis=&quot;x&quot;, rotation=30)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_15_good.png" alt="Rule 15 good chart example">
#   </div>
# </div>

# %% [markdown]
# ### Rule 16 · Visual economy
#
# Use enough visual encoding to explain the data, but avoid redundant styling.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">products = [&quot;A&quot;, &quot;B&quot;, &quot;C&quot;, &quot;D&quot;, &quot;E&quot;, &quot;F&quot;]</span>
# <span class="gv-code-line">values = [18, 25, 22, 31, 27, 20]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.bar(products, values, hatch=&quot;//&quot;, edgecolor=&quot;black&quot;)</span>
# <span class="gv-code-line">ax.plot(products, values, marker=&quot;D&quot;, color=&quot;red&quot;)</span>
# <span class="gv-code-line">ax.grid(True, axis=&quot;both&quot;)</span>
# <span class="gv-code-line">ax.set_title(&quot;Product sales with redundant styling&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_16_bad.png" alt="Rule 16 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">products = [&quot;A&quot;, &quot;B&quot;, &quot;C&quot;, &quot;D&quot;, &quot;E&quot;, &quot;F&quot;]</span>
# <span class="gv-code-line">values = [18, 25, 22, 31, 27, 20]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line added">ax.bar(products, values)</span>
# <span class="gv-code-line added">ax.grid(True, axis=&quot;y&quot;)</span>
# <span class="gv-code-line added">ax.set_title(&quot;Product sales&quot;)</span>
# <span class="gv-code-line added">ax.set_ylabel(&quot;Sales (k EUR)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_16_good.png" alt="Rule 16 good chart example">
#   </div>
# </div>

# %% [markdown]
# ## Integrity rules
#
# Rules 17-25 check whether the chart avoids misleading scale, encoding, or comparison choices.

# %% [markdown]
# ### Rule 17 · Appropriate scale
#
# For bars, a truncated baseline can exaggerate small differences.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">branches = [&quot;North&quot;, &quot;Central&quot;, &quot;South&quot;]</span>
# <span class="gv-code-line">satisfaction = [82, 86, 88]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.bar(branches, satisfaction)</span>
# <span class="gv-code-line">ax.set_ylim(80, 90)</span>
# <span class="gv-code-line">ax.set_title(&quot;Customer satisfaction by branch&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Satisfied customers (%)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_17_bad.png" alt="Rule 17 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">branches = [&quot;North&quot;, &quot;Central&quot;, &quot;South&quot;]</span>
# <span class="gv-code-line">satisfaction = [82, 86, 88]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.bar(branches, satisfaction)</span>
# <span class="gv-code-line added">ax.set_ylim(0, 100)</span>
# <span class="gv-code-line">ax.set_title(&quot;Customer satisfaction by branch&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Satisfied customers (%)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_17_good.png" alt="Rule 17 good chart example">
#   </div>
# </div>

# %% [markdown]
# ### Rule 18 · Suitable chart type
#
# Categorical comparisons are easier to read as bars than as a line that implies sequence.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">products = [&quot;Shoes&quot;, &quot;Bags&quot;, &quot;Watches&quot;, &quot;Perfume&quot;, &quot;Jewelry&quot;]</span>
# <span class="gv-code-line">sales = [54, 31, 46, 28, 62]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.plot(products, sales, marker=&quot;o&quot;)</span>
# <span class="gv-code-line">ax.set_title(&quot;Sales by product category&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Sales (k EUR)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_18_bad.png" alt="Rule 18 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">products = [&quot;Shoes&quot;, &quot;Bags&quot;, &quot;Watches&quot;, &quot;Perfume&quot;, &quot;Jewelry&quot;]</span>
# <span class="gv-code-line">sales = [54, 31, 46, 28, 62]</span>
# <span class="gv-code-line">pairs = sorted(zip(sales, products))</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line added">ax.barh([p for _, p in pairs], [s for s, _ in pairs])</span>
# <span class="gv-code-line">ax.set_title(&quot;Sales by product category&quot;)</span>
# <span class="gv-code-line added">ax.set_xlabel(&quot;Sales (k EUR)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_18_good.png" alt="Rule 18 good chart example">
#   </div>
# </div>

# %% [markdown]
# ### Rule 19 · Color map quality
#
# Continuous color should use a perceptual scale and a labeled color bar.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line">import numpy as np</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">heat = np.outer(np.linspace(0, 1, 12), np.linspace(0.2, 1, 12))</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">image = ax.imshow(heat, cmap=&quot;rainbow&quot;)</span>
# <span class="gv-code-line">ax.set_title(&quot;Demand intensity&quot;)</span>
# <span class="gv-code-line">fig.colorbar(image, ax=ax)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_19_bad.png" alt="Rule 19 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line">import numpy as np</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">heat = np.outer(np.linspace(0, 1, 12), np.linspace(0.2, 1, 12))</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line added">image = ax.imshow(heat, cmap=&quot;viridis&quot;)</span>
# <span class="gv-code-line">ax.set_title(&quot;Demand intensity&quot;)</span>
# <span class="gv-code-line">colorbar = fig.colorbar(image, ax=ax)</span>
# <span class="gv-code-line added">colorbar.set_label(&quot;Orders per store&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_19_good.png" alt="Rule 19 good chart example">
#   </div>
# </div>

# %% [markdown]
# ### Rule 20 · Avoid dual axes
#
# Dual axes can imply relationships that come from scale choices rather than data.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">months = [1, 2, 3, 4, 5, 6]</span>
# <span class="gv-code-line">revenue = [1.2, 1.5, 1.8, 2.1, 2.4, 2.7]</span>
# <span class="gv-code-line">churn = [9, 8, 7, 6, 5, 4]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax1 = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax2 = ax1.twinx()</span>
# <span class="gv-code-line">ax1.plot(months, revenue, marker=&quot;o&quot;, label=&quot;Revenue&quot;)</span>
# <span class="gv-code-line">ax2.plot(months, churn, marker=&quot;o&quot;, color=&quot;red&quot;, label=&quot;Churn&quot;)</span>
# <span class="gv-code-line">ax1.set_ylabel(&quot;Revenue (M EUR)&quot;)</span>
# <span class="gv-code-line">ax2.set_ylabel(&quot;Churn (%)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_20_bad.png" alt="Rule 20 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">months = [1, 2, 3, 4, 5, 6]</span>
# <span class="gv-code-line">revenue = [1.2, 1.5, 1.8, 2.1, 2.4, 2.7]</span>
# <span class="gv-code-line">churn = [9, 8, 7, 6, 5, 4]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line added">fig, axes = plt.subplots(2, 1, figsize=(6.4, 4.2), sharex=True)</span>
# <span class="gv-code-line added">axes[0].plot(months, revenue, marker=&quot;o&quot;)</span>
# <span class="gv-code-line added">axes[0].set_ylabel(&quot;Revenue (M EUR)&quot;)</span>
# <span class="gv-code-line added">axes[1].plot(months, churn, marker=&quot;o&quot;, color=&quot;red&quot;)</span>
# <span class="gv-code-line added">axes[1].set_ylabel(&quot;Churn (%)&quot;)</span>
# <span class="gv-code-line added">axes[1].set_xlabel(&quot;Month&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_20_good.png" alt="Rule 20 good chart example">
#   </div>
# </div>

# %% [markdown]
# ### Rule 21 · Area baseline
#
# Filled areas should use an honest baseline because area size carries meaning.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">years = [2020, 2021, 2022, 2023, 2024, 2025]</span>
# <span class="gv-code-line">share = [62, 64, 66, 67, 69, 70]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.fill_between(years, share, 60)</span>
# <span class="gv-code-line">ax.plot(years, share, marker=&quot;o&quot;)</span>
# <span class="gv-code-line">ax.set_ylim(60, 72)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Share (%)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_21_bad.png" alt="Rule 21 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">years = [2020, 2021, 2022, 2023, 2024, 2025]</span>
# <span class="gv-code-line">share = [62, 64, 66, 67, 69, 70]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line added">ax.fill_between(years, share, 0)</span>
# <span class="gv-code-line">ax.plot(years, share, marker=&quot;o&quot;)</span>
# <span class="gv-code-line added">ax.set_ylim(0, 100)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Share (%)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_21_good.png" alt="Rule 21 good chart example">
#   </div>
# </div>

# %% [markdown]
# ### Rule 22 · Aspect ratio sanity
#
# Extreme aspect ratios can flatten or exaggerate trends.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">quarters = [1, 2, 3, 4, 5, 6, 7, 8]</span>
# <span class="gv-code-line">index = [12, 14, 15, 16, 18, 19, 21, 22]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(7.8, 2.2))</span>
# <span class="gv-code-line">ax.plot(quarters, index, marker=&quot;o&quot;)</span>
# <span class="gv-code-line">ax.set_title(&quot;Compressed aspect ratio hides the trend&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_22_bad.png" alt="Rule 22 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">quarters = [1, 2, 3, 4, 5, 6, 7, 8]</span>
# <span class="gv-code-line">index = [12, 14, 15, 16, 18, 19, 21, 22]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line added">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.plot(quarters, index, marker=&quot;o&quot;)</span>
# <span class="gv-code-line added">ax.set_title(&quot;Balanced aspect ratio shows the trend clearly&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_22_good.png" alt="Rule 22 good chart example">
#   </div>
# </div>

# %% [markdown]
# ### Rule 23 · Histogram bin quality
#
# A histogram needs enough bins to reveal the distribution shape without creating noise.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line">import numpy as np</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">rng = np.random.default_rng(42)</span>
# <span class="gv-code-line">scores = rng.normal(72, 9, 420)</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.hist(scores, bins=3)</span>
# <span class="gv-code-line">ax.set_title(&quot;Exam scores&quot;)</span>
# <span class="gv-code-line">ax.set_xlabel(&quot;Score&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Students&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_23_bad.png" alt="Rule 23 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line">import numpy as np</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">rng = np.random.default_rng(42)</span>
# <span class="gv-code-line">scores = rng.normal(72, 9, 420)</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line added">ax.hist(scores, bins=18)</span>
# <span class="gv-code-line">ax.set_title(&quot;Exam scores&quot;)</span>
# <span class="gv-code-line">ax.set_xlabel(&quot;Score&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Students&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_23_good.png" alt="Rule 23 good chart example">
#   </div>
# </div>

# %% [markdown]
# ### Rule 24 · Category color consistency
#
# The same category should keep the same color throughout a chart.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">quarters = [&quot;Q1&quot;, &quot;Q2&quot;, &quot;Q3&quot;]</span>
# <span class="gv-code-line">desktop = [42, 45, 48]</span>
# <span class="gv-code-line">mobile = [31, 34, 38]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.plot(quarters, desktop, marker=&quot;o&quot;, color=&quot;blue&quot;, label=&quot;Desktop&quot;)</span>
# <span class="gv-code-line">ax.plot(quarters, mobile, marker=&quot;o&quot;, color=&quot;orange&quot;, label=&quot;Mobile&quot;)</span>
# <span class="gv-code-line">ax.scatter([&quot;Q2&quot;], [45], color=&quot;orange&quot;, s=90)</span>
# <span class="gv-code-line">ax.scatter([&quot;Q2&quot;], [34], color=&quot;blue&quot;, s=90)</span>
# <span class="gv-code-line">ax.legend()</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_24_bad.png" alt="Rule 24 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">quarters = [&quot;Q1&quot;, &quot;Q2&quot;, &quot;Q3&quot;]</span>
# <span class="gv-code-line">desktop = [42, 45, 48]</span>
# <span class="gv-code-line">mobile = [31, 34, 38]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line added">ax.plot(quarters, desktop, marker=&quot;o&quot;, color=&quot;blue&quot;, label=&quot;Desktop&quot;)</span>
# <span class="gv-code-line added">ax.plot(quarters, mobile, marker=&quot;o&quot;, color=&quot;orange&quot;, label=&quot;Mobile&quot;)</span>
# <span class="gv-code-line">ax.legend()</span>
# <span class="gv-code-line">ax.set_title(&quot;Traffic by device&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Sessions (k)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_24_good.png" alt="Rule 24 good chart example">
#   </div>
# </div>

# %% [markdown]
# ### Rule 25 · Diverging zero reference
#
# Positive and negative values need a clear zero reference.

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code bad">
#     <details class="gv-code-details">
#       <summary>Bad chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">departments = [&quot;Ops&quot;, &quot;Sales&quot;, &quot;Support&quot;, &quot;Product&quot;]</span>
# <span class="gv-code-line">delta = [-8, 12, -5, 9]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line">ax.bar(departments, delta)</span>
# <span class="gv-code-line">ax.set_title(&quot;Change vs target&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Change (%)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_25_bad.png" alt="Rule 25 bad chart example">
#   </div>
# </div>

# %% [markdown]
# <div class="gv-example-grid">
#   <div class="gv-example-code good">
#     <details class="gv-code-details">
#       <summary>Good chart code</summary>
#       <pre><span class="gv-code-line">import matplotlib.pyplot as plt</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">departments = [&quot;Ops&quot;, &quot;Sales&quot;, &quot;Support&quot;, &quot;Product&quot;]</span>
# <span class="gv-code-line">delta = [-8, 12, -5, 9]</span>
# <span class="gv-code-line added">colors = [&quot;#b42318&quot; if value &lt; 0 else &quot;#2f855a&quot; for value in delta]</span>
# <span class="gv-code-line"> </span>
# <span class="gv-code-line">fig, ax = plt.subplots(figsize=(6.4, 3.8))</span>
# <span class="gv-code-line added">ax.bar(departments, delta, color=colors)</span>
# <span class="gv-code-line added">ax.axhline(0, color=&quot;black&quot;, linewidth=1.2)</span>
# <span class="gv-code-line">ax.set_title(&quot;Change vs target&quot;)</span>
# <span class="gv-code-line">ax.set_ylabel(&quot;Change (%)&quot;)</span>
# <span class="gv-code-line">plt.show()</span></pre>
#     </details>
#   </div>
#   <div class="gv-example-chart">
#     <img src="_static/example_notebook/rule_25_good.png" alt="Rule 25 good chart example">
#   </div>
# </div>
